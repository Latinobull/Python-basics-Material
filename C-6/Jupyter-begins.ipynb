# %%
import pandas
pandas.set_option('display.max_rows', None)

# %%
df1 = pandas.read_csv("employees.csv")

# %%
df1
# Out:
#      Firstname     Lastname                             Email  Age     Salary
# 0       Zondra     Gherardo       Zondra.Gherardo@yopmail.com   48   78133.48
# 1       Felice         Mich           Felice.Mich@yopmail.com   65   63325.30
# 2     Charissa        Ashok        Charissa.Ashok@yopmail.com   58   85752.30
# 3        Misha      Glovsky         Misha.Glovsky@yopmail.com   62  145808.43
# 4       Frieda     Adrienne       Frieda.Adrienne@yopmail.com   20  114615.29
# 5         Lily      Lamoree          Lily.Lamoree@yopmail.com   38  143193.78
# 6      Margalo     Madelene      Margalo.Madelene@yopmail.com   37  104051.00
# 7        Siana      Guthrie         Siana.Guthrie@yopmail.com   29   76308.78
# 8       Lonnie          Rad            Lonnie.Rad@yopmail.com   65   94775.42
# 9        Leona         Bord            Leona.Bord@yopmail.com   25  116976.03
# 10      Marjie       Amadas         Marjie.Amadas@yopmail.com   22   86121.03
# ...

# %%
from bs4 import BeautifulSoup
import requests
print('hi')
# Out:
# hi

# %%
r=requests.get('https://en.wikipedia.org/wiki/Dog')
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Dog - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"df341308-fce4-431b-a2e7-dde121854b5a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Dog","wgTitle":"Dog","wgCurRevisionId":1028422635,"wgRevisionId":1028422635,"wgArticleId":4269567,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Latin-language sources (la)","CS1 maint: uses authors parameter","CS1 German-language sources (de)","CS1: long volume value","CS1 errors: extra text: volume","CS1 maint: extra text: au
# ...

# %%
soup = BeautifulSoup(r.content)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Dog - Wikipedia</title>
# ...

# %%
print('hey')
# Out:
# hey
